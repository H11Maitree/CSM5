# %% [markdown]
# # RGB to grayscale
#
#
# This example converts an image with RGB channels into an image with a single
# grayscale channel.
#
# The value of each grayscale pixel is calculated as the weighted sum of the
# corresponding red, green and blue pixels as::
#
#         Y = 0.2125 R + 0.7154 G + 0.0721 B
#
# These weights are used by CRT phosphors as they better represent human
# perception of red, green and blue than equal weights. [1]_
#
# References
# ----------
# .. [1] http://www.poynton.com/PDFs/ColorFAQ.pdf

# %% [markdown]
# ## rgb2gray( ) function

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray
import imageio

original = imageio.imread("./4917BF37-A12D-4B0A-BB9D-6AF8FB1AF469.jpeg")
grayscale = rgb2gray(original)
plt.imshow(grayscale, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# ## Gray= 0.2125 Red + 0.7154 Green + 0.0721 Blue

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray
import imageio

original = imageio.imread("./4917BF37-A12D-4B0A-BB9D-6AF8FB1AF469.jpeg")
print(original.shape)
tempforgray=0
graypicture=np.zeros((original.shape[0],original.shape[1],3),np.ubyte)
for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        graypicture[y,x,0]= (original[y,x,0]*0.2125)+(original[y,x,1]*0.7154)+(original[y,x,2]*0.0721)
        graypicture[y,x,1]=graypicture[y,x,0]
        graypicture[y,x,2]=graypicture[y,x,0]
        
plt.imshow(graypicture)
plt.show()
# Out:
# (384, 295, 3)

# %% [markdown]
# ## Gray=  (Red + Green + Blue)/3
# PS.Suck

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray
import imageio

original = imageio.imread("./4917BF37-A12D-4B0A-BB9D-6AF8FB1AF469.jpeg")
print(original.shape)
tempforgray=0
graypicture=np.zeros((original.shape[0],original.shape[1],3),np.ubyte)
for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        graypicture[y,x,0]= ((original[y,x,0])+(original[y,x,1])+(original[y,x,2]))/3
        graypicture[y,x,1]=graypicture[y,x,0]
        graypicture[y,x,2]=graypicture[y,x,0]
        
plt.imshow(graypicture)
plt.show()
# Out:
# (384, 295, 3)
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: RuntimeWarning: overflow encountered in ubyte_scalars
#   del sys.path[0]
